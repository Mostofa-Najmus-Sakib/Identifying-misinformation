# %%
import pandas as pd
import networkx as nx

# %%
import pandas as pd
import networkx as nx

user_news_p=pd.read_csv(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_news.csv')
user_news_b=pd.read_excel(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_news_b.xlsx')
user_user_p=pd.read_csv(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_user.csv')
user_user_b=pd.read_excel(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_user_b.xlsx')


user_news_p.info()

B=nx.DiGraph()

G=B.add_weighted_edges_from(
    [(row['News_id'], row['from_User'], 1) for idx, row in user_news_p.iterrows()], 
    weight='shares')

B

nx.number_of_nodes(B)

nx.number_of_edges(B)

B1=nx.DiGraph()

B1.add_weighted_edges_from(
    [(row['News_id'], row['from_User'], 1) for idx, row in user_news_b.iterrows()], 
    weight='shares')

nx.number_of_edges(B1)













all_news_b=pd.read_excel(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\all_news_b.xlsx')
all_news_p=pd.read_excel(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\all_news_p.xlsx')
all_news_b.info()



news_b_merge=pd.merge(all_news_b,user_news_b,how='inner',on='News_id')
news_p_merge=pd.merge(all_news_p,user_news_p,how='inner',on='News_id')

news_b_merge.info()

news_p_merge.info()

user_news_b=user_news_b.rename(columns={'News_id': 'source','from_User':'target'})
user_news_p=user_news_p.rename(columns={'News_id': 'source','from_User':'target'})





user_user_b=user_user_b.rename(columns={'User_influence': 'source','User_follower':'target'})
user_user_p=user_user_p.rename(columns={'User_influence': 'source','User_follower':'target'})

nx.number_of_edges(G_u_b)

nx.number_of_nodes(G_u_b)

nx.write_gexf(G_u_b,r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\G_u_b.gexf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ed5b97963e20> in <module>()
#       2 import networkx as nx
#       3
# ----> 4 user_news_p=pd.read_csv(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_news.csv')
#       5 user_news_b=pd.read_excel(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_news_b.xlsx')
#       6 user_user_p=pd.read_csv(r'C:\Users\Admini\Desktop\SMM\FakeNewsNet-old-version\Data\PolitiFact\user_user.csv')
#
# ...

# %%
B = nx.Graph()
B.add_nodes_from(user_news_p['News_id'], bipartite=0)
B.add_nodes_from(user_news_p['from_User'], bipartite=1)
B.add_weighted_edges_from(
    [(row['News_id'], row['from_User'], 1) for idx, row in user_news_p.iterrows()], 
    weight='shares')
